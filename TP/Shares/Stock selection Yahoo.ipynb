# %%
import requests
import pandas as pd 
from yahoo_fin import stock_info as si 
from pandas_datareader import DataReader
import numpy as np
# Out:
# D:\Anaconda\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
tickers = si.tickers_sp500()
recommendations = []

# %%
only_best = True

# %%
res = []
for ticker in tickers:
    lhs_url = 'https://query2.finance.yahoo.com/v10/finance/quoteSummary/'
    rhs_url = '?formatted=true&crumb=swg7qs5y9UP&lang=en-US&region=US&' \
              'modules=upgradeDowngradeHistory,recommendationTrend,' \
              'financialData,earningsHistory,earningsTrend,industryTrend&' \
              'corsDomain=finance.yahoo.com'
              
    url =  lhs_url + ticker + rhs_url
    r = requests.get(url)
    if not r.ok:
        recommendation = 6
    try:
        result = r.json()['quoteSummary']['result'][0]
        recommendation =result['financialData']['recommendationMean']['fmt']
    except:
        recommendation = 6
    
    recommendations.append(recommendation)
    if only_best:
        if float(recommendation) >= 2:
            continue
    print("--------------------------------------------")
    print ("{} has an average recommendation of: ".format(ticker), recommendation)
    res.append(ticker)
    #time.sleep(0.5)
# Out:
# --------------------------------------------
# ABBV has an average recommendation of:  1.90
# --------------------------------------------
# ADI has an average recommendation of:  1.90
# --------------------------------------------
# AES has an average recommendation of:  1.90
# --------------------------------------------
# AIZ has an average recommendation of:  1.70
# --------------------------------------------
# AJG has an average recommendation of:  1.80
# --------------------------------------------
# AMP has an average recommendation of:  1.80
# --------------------------------------------
# AMZN has an average recommendation of:  1.80
# --------------------------------------------
# ARE has an average recommendation of:  1.80
# --------------------------------------------
# ATVI has an average recommendation of:  1.90
# --------------------------------------------
# BAX has an average recommendation of:  1.90
# --------------------------------------------
# BIO has an average recommendation of:  1.50
# --------------------------------------------
# BKR has an average recommendation of:  1.90
# --------------------------------------------
# BLK has an average recommendation of:  1.90
# --------------------------------------------
# BMY has an average recommendation of:  1.90
# --------------------------------------------
# BSX has an average recommendation of:  1.60
# --------------------------------------------
# C has an average recommendation of:  1.90
# --------------------------------------------
# CI has an average recommendation of:  1.80
# --------------------------------------------
# CNC has an average recommendation of:  1.60
# --------------------------------------------
# COP has an average recommendation of:  1.90
# --------------------------------------------
# CPRT has an average recommendation of:  1.90
# --------------------------------------------
# CRM has an average recommendation of:  1.80
# --------------------------------------------
# CXO has an average recommendation of:  1.80
# --------------------------------------------
# DD has an average recommendation of:  1.90
# --------------------------------------------
# DHR has an average recommendation of:  1.70
# --------------------------------------------
# DXCM has an average recommendation of:  1.60
# --------------------------------------------
# EQIX has an average recommendation of:  1.80
# --------------------------------------------
# FANG has an average recommendation of:  1.80
# --------------------------------------------
# FB has an average recommendation of:  1.80
# --------------------------------------------
# FIS has an average recommendation of:  1.80
# --------------------------------------------
# FISV has an average recommendation of:  1.90
# --------------------------------------------
# FMC has an average recommendation of:  1.90
# --------------------------------------------
# GM has an average recommendation of:  1.90
# --------------------------------------------
# GOOG has an average recommendation of:  1.60
# --------------------------------------------
# GOOGL has an average recommendation of:  1.80
# --------------------------------------------
# GPN has an average recommendation of:  1.80
# --------------------------------------------
# HCA has an average recommendation of:  1.90
# --------------------------------------------
# HOLX has an average recommendation of:  1.80
# --------------------------------------------
# ICE has an average recommendation of:  1.60
# --------------------------------------------
# INFO has an average recommendation of:  1.90
# --------------------------------------------
# IQV has an average recommendation of:  1.80
# --------------------------------------------
# J has an average recommendation of:  1.60
# --------------------------------------------
# JNJ has an average recommendation of:  1.90
# --------------------------------------------
# KEYS has an average recommendation of:  1.70
# --------------------------------------------
# KMX has an average recommendation of:  1.60
# --------------------------------------------
# LDOS has an average recommendation of:  1.80
# --------------------------------------------
# LH has an average recommendation of:  1.80
# --------------------------------------------
# LHX has an average recommendation of:  1.70
# --------------------------------------------
# LKQ has an average recommendation of:  1.60
# --------------------------------------------
# LOW has an average recommendation of:  1.80
# --------------------------------------------
# LVS has an average recommendation of:  1.80
# --------------------------------------------
# MA has an average recommendation of:  1.90
# --------------------------------------------
# MDLZ has an average recommendation of:  1.80
# --------------------------------------------
# MRK has an average recommendation of:  1.90
# --------------------------------------------
# MSFT has an average recommendation of:  1.70
# --------------------------------------------
# NOC has an average recommendation of:  1.90
# --------------------------------------------
# NOW has an average recommendation of:  1.90
# --------------------------------------------
# NRG has an average recommendation of:  1.80
# --------------------------------------------
# PLD has an average recommendation of:  1.90
# --------------------------------------------
# PSX has an average recommendation of:  1.80
# --------------------------------------------
# PWR has an average recommendation of:  1.60
# --------------------------------------------
# PXD has an average recommendation of:  1.80
# --------------------------------------------
# PYPL has an average recommendation of:  1.80
# --------------------------------------------
# SNPS has an average recommendation of:  1.80
# --------------------------------------------
# SYF has an average recommendation of:  1.90
# --------------------------------------------
# TDY has an average recommendation of:  1.70
# --------------------------------------------
# TFX has an average recommendation of:  1.80
# --------------------------------------------
# TJX has an average recommendation of:  1.70
# --------------------------------------------
# TMO has an average recommendation of:  1.70
# --------------------------------------------
# UNH has an average recommendation of:  1.80
# --------------------------------------------
# V has an average recommendation of:  1.80
# --------------------------------------------
# VLO has an average recommendation of:  1.90
# --------------------------------------------
# WMB has an average recommendation of:  1.80
# --------------------------------------------
# WST has an average recommendation of:  1.70
# --------------------------------------------
# WYNN has an average recommendation of:  1.90
# --------------------------------------------
# ZBH has an average recommendation of:  1.90

# %%
    
dataframe = pd.DataFrame(list(zip(tickers, recommendations)), columns =['Company', 'Recommendations']) 
dataframe = dataframe.set_index('Company')
dataframe.to_csv('recommendations.csv')

print (df)
# Out:
# D:\Anaconda\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-4cc811b75c85> in <module>
#       5 import numpy as np
#       6
# ----> 7 tickers = si.tickers_sp500()
#       8 recommendations = []
#       9
#
# D:\Anaconda\lib\site-packages\yahoo_fin\stock_info.py in tickers_sp500()
#      94     # get list of all S&P 500 stocks
#      95     sp500 = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]
# ---> 96     sp_tickers = sp500[0].tolist()
#      97     sp_tickers = [x for x in sp_tickers if x != "Ticker symbol"]
#      98
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
