# %%
import numpy as np
import pandas as pd
from datetime import datetime

import sys

sys.path.append("..") 
from tp_config import *
from tp_utils.tp_utils import daily_returns
from tp_utils.data_provider import read_prices, read_data,load_data_from_exchange
import matplotlib.pyplot as plt

# %%
df_all = read_data('BTC-USDT', '1m')
print(datetime.fromtimestamp(df_all.iloc[-1]['T']/1000))
# Out:
# 2021-05-08 19:59:00

# %%
prices = prices_all[-10000:]

# %%
rets = np.diff(np.log(prices))

# %%
plt.hist(rets, bins = 30)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.000e+00,
#         1.000e+00, 2.000e+00, 4.000e+00, 1.600e+01, 3.700e+01, 2.010e+02,
#         8.780e+02, 2.722e+03, 3.780e+03, 1.710e+03, 4.650e+02, 1.230e+02,
#         4.100e+01, 8.000e+00, 3.000e+00, 1.000e+00, 1.000e+00, 1.000e+00]),
#  array([-0.01716128, -0.01631503, -0.01546878, -0.01462253, -0.01377628,
#         -0.01293003, -0.01208378, -0.01123753, -0.01039128, -0.00954503,
#         -0.00869878, -0.00785253, -0.00700628, -0.00616003, -0.00531378,
#         -0.00446753, -0.00362128, -0.00277504, -0.00192879, -0.00108254,
#         -0.00023629,  0.00060996,  0.00145621,  0.00230246,  0.00314871,
#          0.00399496,  0.00484121,  0.00568746,  0.00653371,  0.00737996,
#          0.00822621]),
#  <BarContainer object of 30 artists>)

# %%
buy_signal = rets < -0.002

# %%
for buy, price in zip(buy_signal, prices[1:]):
    if buy:
        print(price)
# Out:
# 56692.1
# 56560.74
# 56400.0
# 56463.5
# 56284.77
# 56646.83
# 56430.01
# 56249.11
# 56391.75
# 56198.86
# 56117.45
# 56613.8
# 56514.73
# 56600.0
# 56386.03
# 56216.73
# 57818.19
# 58611.36
# 58424.96
# 58121.84
# 57799.34
# 57393.55
# 57694.57
# 57642.58
# 57434.68
# 57437.01
# 57266.09
# 57426.27
# 57823.1
# 57012.16
# 56816.55
# 56807.89
# 57015.55
# 56816.89
# 56544.03
# 56595.41
# 56353.4
# 55574.4
# 54644.36
# 55198.69
# 55555.01
# 55377.29
# 55380.67
# 55488.07
# 55831.12
# 55730.62
# 55695.16
# 55565.73
# 55733.34
# 55304.23
# 55738.47
# 55672.34
# 55614.52
# 55529.22
# 56112.58
# 55775.98
# 55531.35
# 55243.77
# 55331.42
# 55130.03
# 55103.44
# 55275.2
# 55198.48
# 54753.22
# 54560.89
# 54904.31
# 54621.76
# 54481.8
# 54339.98
# 54402.11
# 54134.68
# 53850.96
# 53561.59
# 53702.02
# 54334.26
# 54200.0
# 53899.09
# 53799.33
# 53515.75
# 53909.54
# 53900.01
# 54020.21
# 53891.92
# 53771.42
# 53652.18
# 53763.89
# 53257.26
# 53335.89
# 53910.0
# 53821.1
# 54050.76
# 54278.99
# ...
