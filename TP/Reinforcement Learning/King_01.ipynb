# %%
import numpy as np
import pandas as pd
import random
import json
import gym
from gym import spaces

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
# Out:
# d:\anaconda\envs\stable\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\anaconda\envs\stable\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
MAX_ACCOUNT_BALANCE = 2147483647
MAX_NUM_SHARES = 2147483647
MAX_SHARE_PRICE = 5000
MAX_OPEN_POSITIONS = 5
MAX_STEPS = 20000

INITIAL_ACCOUNT_BALANCE = 10000

class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(StockTradingEnv, self).__init__()

        self.df = df
        self.reward_range = (0, MAX_ACCOUNT_BALANCE)

        # Actions of the format Buy x%, Sell x%, Hold, etc.
        self.action_space = spaces.Box(
            low=np.array([0, 0]), high=np.array([3, 1]))

        # Prices contains the OHCL values for the last five prices
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(6, 6))

    def _next_observation(self):
        # Get the stock data points for the last 5 days and scale to between 0-1
        frame = np.array([
            self.df.loc[self.current_step: self.current_step +
                        5, 'Open'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'High'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Low'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Close'].values / MAX_SHARE_PRICE,
            self.df.loc[self.current_step: self.current_step +
                        5, 'Volume'].values / MAX_NUM_SHARES,
        ])

        # Append additional data and scale each value to between 0-1
        obs = np.append(frame, [[
            self.balance / MAX_ACCOUNT_BALANCE,
            self.max_net_worth / MAX_ACCOUNT_BALANCE,
            self.shares_held / MAX_NUM_SHARES,
            self.cost_basis / MAX_SHARE_PRICE,
            self.total_shares_sold / MAX_NUM_SHARES,
            self.total_sales_value / (MAX_NUM_SHARES * MAX_SHARE_PRICE),
        ]], axis=0)

        return obs

    def _take_action(self, action):
        # Set the current price to a random price within the time step
        current_price = random.uniform(
            self.df.loc[self.current_step, "Open"], self.df.loc[self.current_step, "Close"])

        action_type = action[0]
        amount = action[1]

        if action_type < 1:
            # Buy amount % of balance in shares
            total_possible = int(self.balance / current_price)
            shares_bought = int(total_possible * amount)
            prev_cost = self.cost_basis * self.shares_held
            additional_cost = shares_bought * current_price

            self.balance -= additional_cost
            self.cost_basis = (
                prev_cost + additional_cost) / (self.shares_held + shares_bought)
            self.shares_held += shares_bought

        elif action_type < 2:
            # Sell amount % of shares held
            shares_sold = int(self.shares_held * amount)
            self.balance += shares_sold * current_price
            self.shares_held -= shares_sold
            self.total_shares_sold += shares_sold
            self.total_sales_value += shares_sold * current_price

        self.net_worth = self.balance + self.shares_held * current_price

        if self.net_worth > self.max_net_worth:
            self.max_net_worth = self.net_worth

        if self.shares_held == 0:
            self.cost_basis = 0

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        if self.current_step > len(self.df.loc[:, 'Open'].values) - 6:
            self.current_step = 0

        delay_modifier = (self.current_step / MAX_STEPS)

        reward = self.balance * delay_modifier
        done = self.net_worth <= 0

        obs = self._next_observation()

        return obs, reward, done, {}

    def reset(self):
        # Reset the state of the environment to an initial state
        self.balance = INITIAL_ACCOUNT_BALANCE
        self.net_worth = INITIAL_ACCOUNT_BALANCE
        self.max_net_worth = INITIAL_ACCOUNT_BALANCE
        self.shares_held = 0
        self.cost_basis = 0
        self.total_shares_sold = 0
        self.total_sales_value = 0

        # Set the current step to a random point within the data frame
        self.current_step = random.randint(
            0, len(self.df.loc[:, 'Open'].values) - 6)

        return self._next_observation()

    def render(self, mode='human', close=False):
        # Render the environment to the screen
        profit = self.net_worth - INITIAL_ACCOUNT_BALANCE

        print(f'Step: {self.current_step}')
        print(f'Balance: {self.balance}')
        print(
            f'Shares held: {self.shares_held} (Total sold: {self.total_shares_sold})')
        print(
            f'Avg cost for held shares: {self.cost_basis} (Total sales value: {self.total_sales_value})')
        print(
            f'Net worth: {self.net_worth} (Max net worth: {self.max_net_worth})')
        print(f'Profit: {profit}')
        print(' ')

# %%
import gym
import json
import datetime as dt


df = pd.read_csv('AAPL.csv')
df = df.sort_values('Date')

# The algorithms require a vectorized environment to run
env = DummyVecEnv([lambda: StockTradingEnv(df)])

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=20000)
obs = env.reset()
for i in range(2000):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
# Out:
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001904625DB48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001904625DB48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001904625DB48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001904625DB48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x0000019046203E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x0000019046203E48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x0000019046203E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x0000019046203E48>>: AttributeError: module 'gast' has no attribute 'Num'
# d:\anaconda\envs\stable\lib\site-packages\ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in double_scalars
# ---------------------------------------
# | approxkl           | 1.0492344e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | 1.91e-06       |
# | fps                | 187            |
# | n_updates          | 1              |
# | policy_entropy     | 2.837986       |
# | policy_loss        | -6.1024388e-05 |
# | serial_timesteps   | 128            |
# | time_elapsed       | 0              |
# | total_timesteps    | 128            |
# | value_loss         | 5346034.0      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.063694e-07   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.55e-06      |
# | fps                | 429            |
# | n_updates          | 2              |
# | policy_entropy     | 2.8388157      |
# | policy_loss        | -0.00033527066 |
# | serial_timesteps   | 256            |
# | time_elapsed       | 0.684          |
# | total_timesteps    | 256            |
# | value_loss         | 11660067.0     |
# ---------------------------------------
# ----------------------------------------
# | approxkl           | 6.5467486e-07   |
# | clipfrac           | 0.0             |
# | explained_variance | -2.15e-06       |
# | fps                | 420             |
# | n_updates          | 3               |
# | policy_entropy     | 2.8405542       |
# | policy_loss        | -0.000117043615 |
# | serial_timesteps   | 384             |
# | time_elapsed       | 0.983           |
# | total_timesteps    | 384             |
# | value_loss         | 19484622.0      |
# ----------------------------------------
# ---------------------------------------
# | approxkl           | 1.3635193e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | 2.09e-06       |
# | fps                | 419            |
# | n_updates          | 4              |
# | policy_entropy     | 2.8413177      |
# | policy_loss        | -2.1449698e-05 |
# | serial_timesteps   | 512            |
# | time_elapsed       | 1.29           |
# | total_timesteps    | 512            |
# | value_loss         | 24196620.0     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.566487e-08  |
# | clipfrac           | 0.0           |
# | explained_variance | 1.01e-06      |
# | fps                | 427           |
# | n_updates          | 5             |
# | policy_entropy     | 2.8416529     |
# | policy_loss        | -4.183373e-05 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 1.59          |
# | total_timesteps    | 640           |
# | value_loss         | 172007340.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.1040925e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -9.42e-06     |
# | fps                | 426           |
# | n_updates          | 6             |
# | policy_entropy     | 2.8392832     |
# | policy_loss        | -0.0004885462 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 1.89          |
# | total_timesteps    | 768           |
# | value_loss         | 96542690.0    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.1564932e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -9.66e-06      |
# | fps                | 423            |
# | n_updates          | 7              |
# | policy_entropy     | 2.8338466      |
# | policy_loss        | -0.00023755617 |
# | serial_timesteps   | 896            |
# | time_elapsed       | 2.2            |
# | total_timesteps    | 896            |
# | value_loss         | 52609540.0     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.5329151e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.46e-06      |
# | fps                | 423           |
# | n_updates          | 8             |
# | policy_entropy     | 2.829972      |
# | policy_loss        | -0.0013085685 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 2.5           |
# | total_timesteps    | 1024          |
# | value_loss         | 163115200.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.429831e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -3.7e-06      |
# | fps                | 412           |
# | n_updates          | 9             |
# | policy_entropy     | 2.8297408     |
# | policy_loss        | -0.0013414304 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 2.8           |
# | total_timesteps    | 1152          |
# | value_loss         | 97234350.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011502324 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.21e-06      |
# | fps                | 422           |
# | n_updates          | 10            |
# | policy_entropy     | 2.830696      |
# | policy_loss        | -0.002246245  |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 3.11          |
# | total_timesteps    | 1280          |
# | value_loss         | 958163400.0   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005094573  |
# | clipfrac           | 0.0           |
# | explained_variance | 2.74e-06      |
# | fps                | 418           |
# | n_updates          | 11            |
# | policy_entropy     | 2.8305888     |
# | policy_loss        | -0.0033830618 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 3.42          |
# | total_timesteps    | 1408          |
# | value_loss         | 415622460.0   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00090031757  |
# | clipfrac           | 0.0            |
# | explained_variance | -4.65e-06      |
# | fps                | 425            |
# | n_updates          | 12             |
# | policy_entropy     | 2.8291464      |
# | policy_loss        | -0.00086796447 |
# | serial_timesteps   | 1536           |
# | time_elapsed       | 3.72           |
# | total_timesteps    | 1536           |
# | value_loss         | 5146687000.0   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00077320065 |
# | clipfrac           | 0.005859375   |
# | explained_variance | -2.86e-06     |
# | fps                | 423           |
# | n_updates          | 13            |
# | policy_entropy     | 2.8251746     |
# | policy_loss        | -0.0061609875 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 4.03          |
# | total_timesteps    | 1664          |
# | value_loss         | 5224460000.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0042516105  |
# | clipfrac           | 0.0546875     |
# | explained_variance | -3.46e-06     |
# | fps                | 426           |
# | n_updates          | 14            |
# | policy_entropy     | 2.8251715     |
# | policy_loss        | -0.0035710027 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 4.33          |
# | total_timesteps    | 1792          |
# | value_loss         | 4012832000.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033017865 |
# | clipfrac           | 0.0           |
# | explained_variance | 9.3e-06       |
# | fps                | 428           |
# | n_updates          | 15            |
# | policy_entropy     | 2.827101      |
# | policy_loss        | 0.0015709094  |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 4.63          |
# | total_timesteps    | 1920          |
# | value_loss         | 9416431000.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003320335  |
# | clipfrac           | 0.0           |
# | explained_variance | 1.67e-06      |
# | fps                | 421           |
# | n_updates          | 16            |
# | policy_entropy     | 2.8265495     |
# | policy_loss        | -0.0026205224 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 4.93          |
# | total_timesteps    | 2048          |
# | value_loss         | 21673492000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021716058  |
# | clipfrac           | 0.0078125     |
# | explained_variance | 3.4e-06       |
# | fps                | 411           |
# | n_updates          | 17            |
# | policy_entropy     | 2.8260858     |
# | policy_loss        | 0.0009274925  |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 5.24          |
# | total_timesteps    | 2176          |
# | value_loss         | 12031459000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026129454 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.58e-07     |
# | fps                | 428           |
# | n_updates          | 18            |
# | policy_entropy     | 2.826542      |
# | policy_loss        | 0.00036121928 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 5.55          |
# | total_timesteps    | 2304          |
# | value_loss         | 30006278000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.281033e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -1.43e-06     |
# | fps                | 421           |
# | n_updates          | 19            |
# | policy_entropy     | 2.8281035     |
# | policy_loss        | 0.00017381192 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 5.85          |
# | total_timesteps    | 2432          |
# | value_loss         | 16957913000.0 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027610097 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.81e-05      |
# | fps                | 427           |
# | n_updates          | 20            |
# | policy_entropy     | 2.8287952     |
# | policy_loss        | 0.0008633047  |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 6.15          |
# | total_timesteps    | 2560          |
# | value_loss         | 3209497900.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.3362255e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.19e-06     |
# | fps                | 426           |
# | n_updates          | 21            |
# | policy_entropy     | 2.8284113     |
# | policy_loss        | 0.00042062602 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 6.45          |
# | total_timesteps    | 2688          |
# | value_loss         | 587846100.0   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007471856 |
# | clipfrac           | 0.0          |
# | explained_variance | 5.48e-06     |
# | fps                | 422          |
# | n_updates          | 22           |
# | policy_entropy     | 2.827897     |
# | policy_loss        | -0.005995436 |
# | serial_timesteps   | 2816         |
# | time_elapsed       | 6.76         |
# | total_timesteps    | 2816         |
# | value_loss         | 506619230.0  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0021487141 |
# | clipfrac           | 0.017578125  |
# | explained_variance | 9.18e-06     |
# | fps                | 422          |
# | n_updates          | 23           |
# | policy_entropy     | 2.8304543    |
# | policy_loss        | -0.01343444  |
# | serial_timesteps   | 2944         |
# | time_elapsed       | 7.06         |
# | total_timesteps    | 2944         |
# | value_loss         | 842588300.0  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0023300075 |
# | clipfrac           | 0.009765625  |
# | explained_variance | -3.58e-07    |
# | fps                | 427          |
# | n_updates          | 24           |
# | policy_entropy     | 2.8318467    |
# | policy_loss        | -0.005312074 |
# | serial_timesteps   | 3072         |
# | time_elapsed       | 7.36         |
# | total_timesteps    | 3072         |
# | value_loss         | 484770340.0  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00084711635 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.38e-06     |
# | fps                | 422           |
# | n_updates          | 25            |
# | policy_entropy     | 2.8304198     |
# | policy_loss        | -0.001322112  |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 7.66          |
# | total_timesteps    | 3200          |
# | value_loss         | 1753349600.0  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006373521  |
# | clipfrac           | 0.0           |
# | explained_variance | -9.78e-06     |
# | fps                | 427           |
# | n_updates          | 26            |
# | policy_entropy     | 2.8316588     |
# | policy_loss        | -0.0030299197 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 7.97          |
# | total_timesteps    | 3328          |
# | value_loss         | 3299648500.0  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013066414 |
# | clipfrac           | 0.0          |
# | explained_variance | -2.38e-06    |
# | fps                | 407          |
# | n_updates          | 27           |
# | policy_entropy     | 2.8337812    |
# | policy_loss        | -0.005964413 |
# | serial_timesteps   | 3456         |
# | time_elapsed       | 8.27         |
# | total_timesteps    | 3456         |
# | value_loss         | 7098068000.0 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0021647261 |
# | clipfrac           | 0.001953125  |
# | explained_variance | 1.1e-05      |
# | fps                | 431          |
# | n_updates          | 28           |
# | policy_entropy     | 2.8328066    |
# | policy_loss        | 0.0023826098 |
# | serial_timesteps   | 3584         |
# | time_elapsed       | 8.58         |
# | total_timesteps    | 3584         |
# | value_loss         | 8972512000.0 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00016142105 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000242      |
# | fps                | 426           |
# | n_updates          | 29            |
# | policy_entropy     | 2.8328846     |
# | policy_loss        | -0.0019588908 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 8.88          |
# | total_timesteps    | 3712          |
# | value_loss         | 49436.61      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0025105686  |
# | clipfrac           | 0.015625      |
# | explained_variance | -0.00045      |
# | fps                | 427           |
# | n_updates          | 30            |
# | policy_entropy     | 2.8340616     |
# | policy_loss        | -0.0073450184 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 9.18          |
# | total_timesteps    | 3840          |
# | value_loss         | 230797.42     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010987094 |
# | clipfrac           | 0.005859375  |
# | explained_variance | -0.000724    |
# | fps                | 426          |
# | n_updates          | 31           |
# | policy_entropy     | 2.836275     |
# | policy_loss        | -0.006091919 |
# | serial_timesteps   | 3968         |
# | time_elapsed       | 9.48         |
# | total_timesteps    | 3968         |
# | value_loss         | 253820.75    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0020734235 |
# | clipfrac           | 0.01171875   |
# | explained_variance | -0.000498    |
# | fps                | 419          |
# | n_updates          | 32           |
# | policy_entropy     | 2.8367753    |
# | policy_loss        | -0.008060024 |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 9.78         |
# | total_timesteps    | 4096         |
# | value_loss         | 3473348.0    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0018043921 |
# | clipfrac           | 0.0078125    |
# | explained_variance | 0.000996     |
# | fps                | 425          |
# | n_updates          | 33           |
# | policy_entropy     | 2.8369222    |
# | policy_loss        | -0.009676417 |
# | serial_timesteps   | 4224         |
# | time_elapsed       | 10.1         |
# | total_timesteps    | 4224         |
# | value_loss         | 3435322.5    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0017342721 |
# | clipfrac           | 0.0078125    |
# | explained_variance | 0.000338     |
# | fps                | 424          |
# | n_updates          | 34           |
# | policy_entropy     | 2.8367443    |
# | policy_loss        | -0.009639734 |
# | serial_timesteps   | 4352         |
# | time_elapsed       | 10.4         |
# | total_timesteps    | 4352         |
# | value_loss         | 905507.75    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00072472333 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000253      |
# | fps                | 424           |
# | n_updates          | 35            |
# | policy_entropy     | 2.8376527     |
# | policy_loss        | -0.0008163749 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 10.7          |
# | total_timesteps    | 4480          |
# | value_loss         | 863904.25     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040880815 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000134      |
# | fps                | 424           |
# | n_updates          | 36            |
# | policy_entropy     | 2.8383343     |
# | policy_loss        | -0.003214471  |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 11            |
# | total_timesteps    | 4608          |
# | value_loss         | 299118.88     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001424693   |
# | clipfrac           | 0.005859375   |
# | explained_variance | 0.000373      |
# | fps                | 418           |
# | n_updates          | 37            |
# | policy_entropy     | 2.838449      |
# | policy_loss        | -0.0013396824 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 11.3          |
# | total_timesteps    | 4736          |
# | value_loss         | 720953.3      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029436382 |
# | clipfrac           | 0.0           |
# | explained_variance | 9.6e-06       |
# | fps                | 426           |
# | n_updates          | 38            |
# | policy_entropy     | 2.8389137     |
# | policy_loss        | 0.0011434772  |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 11.6          |
# | total_timesteps    | 4864          |
# | value_loss         | 904043.7      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.6813514e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.6e-05       |
# | fps                | 421           |
# | n_updates          | 39            |
# | policy_entropy     | 2.8406        |
# | policy_loss        | 0.0011109507  |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 4992          |
# | value_loss         | 742687.3      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018500534 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.32e-05     |
# | fps                | 426           |
# | n_updates          | 40            |
# | policy_entropy     | 2.8413782     |
# | policy_loss        | -0.0019277609 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 5120          |
# | value_loss         | 3750665.5     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00045320953 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000119     |
# | fps                | 420           |
# | n_updates          | 41            |
# | policy_entropy     | 2.8403144     |
# | policy_loss        | -0.0015863007 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 12.5          |
# | total_timesteps    | 5248          |
# | value_loss         | 2774421.8     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010658538 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -8.27e-05    |
# | fps                | 427          |
# | n_updates          | 42           |
# | policy_entropy     | 2.8384304    |
# | policy_loss        | 0.000432548  |
# | serial_timesteps   | 5376         |
# | time_elapsed       | 12.8         |
# | total_timesteps    | 5376         |
# | value_loss         | 8253252.0    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.001003826  |
# | clipfrac           | 0.0          |
# | explained_variance | -4.98e-05    |
# | fps                | 424          |
# | n_updates          | 43           |
# | policy_entropy     | 2.837441     |
# | policy_loss        | 0.0060529774 |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 13.1         |
# | total_timesteps    | 5504         |
# | value_loss         | 1570293.5    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 8.099796e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 2.6e-05      |
# | fps                | 427          |
# | n_updates          | 44           |
# | policy_entropy     | 2.8363311    |
# | policy_loss        | 0.0008500614 |
# | serial_timesteps   | 5632         |
# | time_elapsed       | 13.4         |
# | total_timesteps    | 5632         |
# | value_loss         | 7927818.5    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012514703  |
# | clipfrac           | 0.00390625    |
# | explained_variance | -6.04e-05     |
# | fps                | 419           |
# | n_updates          | 45            |
# | policy_entropy     | 2.8364544     |
# | policy_loss        | 0.00052195764 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 13.7          |
# | total_timesteps    | 5760          |
# | value_loss         | 8060397.5     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00091566273 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.57e-05      |
# | fps                | 418           |
# | n_updates          | 46            |
# | policy_entropy     | 2.836564      |
# | policy_loss        | -0.0069334265 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 14            |
# | total_timesteps    | 5888          |
# | value_loss         | 5019181.5     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012877224  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000115     |
# | fps                | 419           |
# | n_updates          | 47            |
# | policy_entropy     | 2.8360076     |
# | policy_loss        | -0.0010653648 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 14.3          |
# | total_timesteps    | 6016          |
# | value_loss         | 12082526.0    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00043609942  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.000111       |
# | fps                | 423            |
# | n_updates          | 48             |
# | policy_entropy     | 2.8351111      |
# | policy_loss        | -0.00032306823 |
# | serial_timesteps   | 6144           |
# | time_elapsed       | 14.6           |
# | total_timesteps    | 6144           |
# | value_loss         | 18929758.0     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00033901926 |
# | clipfrac           | 0.0           |
# | explained_variance | 4.27e-05      |
# | fps                | 427           |
# | n_updates          | 49            |
# | policy_entropy     | 2.834298      |
# | policy_loss        | 0.0005744583  |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 14.9          |
# | total_timesteps    | 6272          |
# | value_loss         | 20147732.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008793668  |
# | clipfrac           | 0.0           |
# | explained_variance | -4.68e-05     |
# | fps                | 427           |
# | n_updates          | 50            |
# | policy_entropy     | 2.8349996     |
# | policy_loss        | -0.0054825777 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 15.2          |
# | total_timesteps    | 6400          |
# | value_loss         | 18584594.0    |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.001693882 |
# | clipfrac           | 0.00390625  |
# | explained_variance | -7.63e-06   |
# | fps                | 424         |
# | n_updates          | 51          |
# | policy_entropy     | 2.8356571   |
# | policy_loss        | 0.004354392 |
# | serial_timesteps   | 6528        |
# | time_elapsed       | 15.5        |
# | total_timesteps    | 6528        |
# | value_loss         | 15670818.0  |
# ------------------------------------
# --------------------------------------
# | approxkl           | 0.00031030987 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.38e-05     |
# | fps                | 423           |
# | n_updates          | 52            |
# | policy_entropy     | 2.8351915     |
# | policy_loss        | -0.0026193326 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 15.8          |
# | total_timesteps    | 6656          |
# | value_loss         | 21015292.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0037082098  |
# | clipfrac           | 0.04296875    |
# | explained_variance | -1.92e-05     |
# | fps                | 425           |
# | n_updates          | 53            |
# | policy_entropy     | 2.8339522     |
# | policy_loss        | -0.0042541167 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 16.2          |
# | total_timesteps    | 6784          |
# | value_loss         | 23596578.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00031518604 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.38e-07      |
# | fps                | 427           |
# | n_updates          | 54            |
# | policy_entropy     | 2.8331378     |
# | policy_loss        | 0.0011547944  |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 16.5          |
# | total_timesteps    | 6912          |
# | value_loss         | 26244422.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009696806  |
# | clipfrac           | 0.0           |
# | explained_variance | -3.58e-06     |
# | fps                | 426           |
# | n_updates          | 55            |
# | policy_entropy     | 2.8327363     |
# | policy_loss        | 0.00044355972 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 16.8          |
# | total_timesteps    | 7040          |
# | value_loss         | 35222880.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013648678 |
# | clipfrac           | 0.0           |
# | explained_variance | -8.94e-06     |
# | fps                | 421           |
# | n_updates          | 56            |
# | policy_entropy     | 2.8322165     |
# | policy_loss        | 0.0003427508  |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 17.1          |
# | total_timesteps    | 7168          |
# | value_loss         | 40276936.0    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048647396 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.96e-07     |
# | fps                | 412           |
# | n_updates          | 57            |
# | policy_entropy     | 2.8319557     |
# | policy_loss        | -0.0009845113 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 17.4          |
# | total_timesteps    | 7296          |
# | value_loss         | 45559330.0    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0015612696 |
# | clipfrac           | 0.00390625   |
# | explained_variance | 3.64e-06     |
# | fps                | 424          |
# | n_updates          | 58           |
# | policy_entropy     | 2.8323114    |
# | policy_loss        | -0.00720021  |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 17.7         |
# | total_timesteps    | 7424         |
# | value_loss         | 37588984.0   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.003458447   |
# | clipfrac           | 0.021484375   |
# | explained_variance | -2.74e-06     |
# | fps                | 425           |
# | n_updates          | 59            |
# | policy_entropy     | 2.8331954     |
# | policy_loss        | -0.0059620603 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 18            |
# | total_timesteps    | 7552          |
# | value_loss         | 37526772.0    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017233733 |
# | clipfrac           | 0.0          |
# | explained_variance | -1.19e-06    |
# | fps                | 422          |
# | n_updates          | 60           |
# | policy_entropy     | 2.833603     |
# | policy_loss        | 0.0011584586 |
# | serial_timesteps   | 7680         |
# | time_elapsed       | 18.3         |
# | total_timesteps    | 7680         |
# | value_loss         | 45299216.0   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 2.136732e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.000297       |
# | fps                | 426            |
# | n_updates          | 61             |
# | policy_entropy     | 2.834635       |
# | policy_loss        | -0.00012227925 |
# | serial_timesteps   | 7808           |
# | time_elapsed       | 18.6           |
# | total_timesteps    | 7808           |
# | value_loss         | 2810352.0      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00017551723 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.78e-05     |
# | fps                | 427           |
# | n_updates          | 62            |
# | policy_entropy     | 2.8355842     |
# | policy_loss        | -0.0014507717 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 18.9          |
# | total_timesteps    | 7936          |
# | value_loss         | 2570466.5     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005316955 |
# | clipfrac           | 0.0          |
# | explained_variance | 9.27e-05     |
# | fps                | 419          |
# | n_updates          | 63           |
# | policy_entropy     | 2.83522      |
# | policy_loss        | -0.003767866 |
# | serial_timesteps   | 8064         |
# | time_elapsed       | 19.2         |
# | total_timesteps    | 8064         |
# | value_loss         | 2243284.0    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0011138384   |
# | clipfrac           | 0.005859375    |
# | explained_variance | 5.48e-05       |
# | fps                | 427            |
# | n_updates          | 64             |
# | policy_entropy     | 2.8341186      |
# | policy_loss        | -0.00028585724 |
# | serial_timesteps   | 8192           |
# | time_elapsed       | 19.5           |
# | total_timesteps    | 8192           |
# | value_loss         | 1770468.2      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.844322e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -5.76e-05     |
# | fps                | 426           |
# | n_updates          | 65            |
# | policy_entropy     | 2.8336163     |
# | policy_loss        | -0.0014333286 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 19.8          |
# | total_timesteps    | 8320          |
# | value_loss         | 1728273.0     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012695995  |
# | clipfrac           | 0.00390625    |
# | explained_variance | -8.03e-05     |
# | fps                | 416           |
# | n_updates          | 66            |
# | policy_entropy     | 2.8334103     |
# | policy_loss        | -0.0033969465 |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 20.1          |
# | total_timesteps    | 8448          |
# | value_loss         | 4019115.2     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00055716094 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.78e-05     |
# | fps                | 413           |
# | n_updates          | 67            |
# | policy_entropy     | 2.8348615     |
# | policy_loss        | -0.0035066907 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 20.4          |
# | total_timesteps    | 8576          |
# | value_loss         | 5481050.0     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002333292  |
# | clipfrac           | 0.0078125    |
# | explained_variance | -2.05e-05    |
# | fps                | 425          |
# | n_updates          | 68           |
# | policy_entropy     | 2.8359652    |
# | policy_loss        | -0.008635549 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 20.7         |
# | total_timesteps    | 8704         |
# | value_loss         | 7142227.5    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0014228157 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.000547     |
# | fps                | 424          |
# | n_updates          | 69           |
# | policy_entropy     | 2.835954     |
# | policy_loss        | 0.004124533  |
# | serial_timesteps   | 8832         |
# | time_elapsed       | 21           |
# | total_timesteps    | 8832         |
# | value_loss         | 5150850.5    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 8.2279665e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00455       |
# | fps                | 423           |
# | n_updates          | 70            |
# | policy_entropy     | 2.835751      |
# | policy_loss        | 0.0007641474  |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 21.3          |
# | total_timesteps    | 8960          |
# | value_loss         | 1014.6142     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.6285204e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.000981      |
# | fps                | 423            |
# | n_updates          | 71             |
# | policy_entropy     | 2.836401       |
# | policy_loss        | -4.1683787e-05 |
# | serial_timesteps   | 9088           |
# | time_elapsed       | 21.6           |
# | total_timesteps    | 9088           |
# | value_loss         | 9968.518       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.001787518  |
# | clipfrac           | 0.009765625  |
# | explained_variance | -0.00138     |
# | fps                | 428          |
# | n_updates          | 72           |
# | policy_entropy     | 2.8366947    |
# | policy_loss        | -0.008575705 |
# | serial_timesteps   | 9216         |
# | time_elapsed       | 21.9         |
# | total_timesteps    | 9216         |
# | value_loss         | 14353.606    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0043797316 |
# | clipfrac           | 0.0625       |
# | explained_variance | -0.000329    |
# | fps                | 427          |
# | n_updates          | 73           |
# | policy_entropy     | 2.8363788    |
# | policy_loss        | 0.006577066  |
# | serial_timesteps   | 9344         |
# | time_elapsed       | 22.2         |
# | total_timesteps    | 9344         |
# | value_loss         | 72881.375    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00065495144 |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.00207       |
# | fps                | 429           |
# | n_updates          | 74            |
# | policy_entropy     | 2.8358126     |
# | policy_loss        | -0.0039111595 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 22.5          |
# | total_timesteps    | 9472          |
# | value_loss         | 92670.945     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00028190966 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00331       |
# | fps                | 427           |
# | n_updates          | 75            |
# | policy_entropy     | 2.8345091     |
# | policy_loss        | 0.0028802028  |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 22.8          |
# | total_timesteps    | 9600          |
# | value_loss         | 16303.838     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0019522917 |
# | clipfrac           | 0.01171875   |
# | explained_variance | 0.0007       |
# | fps                | 405          |
# | n_updates          | 76           |
# | policy_entropy     | 2.8334227    |
# | policy_loss        | -0.008248098 |
# | serial_timesteps   | 9728         |
# | time_elapsed       | 23.1         |
# | total_timesteps    | 9728         |
# | value_loss         | 20895.344    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00066353264 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000755     |
# | fps                | 427           |
# | n_updates          | 77            |
# | policy_entropy     | 2.8312716     |
# | policy_loss        | 0.0022407589  |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 23.4          |
# | total_timesteps    | 9856          |
# | value_loss         | 28077.693     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.8044344e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00111       |
# | fps                | 428           |
# | n_updates          | 78            |
# | policy_entropy     | 2.8303552     |
# | policy_loss        | 0.0003860467  |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 23.7          |
# | total_timesteps    | 9984          |
# | value_loss         | 31662.045     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0014949138 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.000149     |
# | fps                | 417          |
# | n_updates          | 79           |
# | policy_entropy     | 2.8300655    |
# | policy_loss        | 0.0025488269 |
# | serial_timesteps   | 10112        |
# | time_elapsed       | 24           |
# | total_timesteps    | 10112        |
# | value_loss         | 23726.727    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.000486408    |
# | clipfrac           | 0.0            |
# | explained_variance | 1.16e-05       |
# | fps                | 425            |
# | n_updates          | 80             |
# | policy_entropy     | 2.8297653      |
# | policy_loss        | -0.00092544593 |
# | serial_timesteps   | 10240          |
# | time_elapsed       | 24.3           |
# | total_timesteps    | 10240          |
# | value_loss         | 72932.984      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00022176023 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000176     |
# | fps                | 427           |
# | n_updates          | 81            |
# | policy_entropy     | 2.8296297     |
# | policy_loss        | -0.0038837236 |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 24.6          |
# | total_timesteps    | 10368         |
# | value_loss         | 162750.17     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003109694  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000153     |
# | fps                | 422           |
# | n_updates          | 82            |
# | policy_entropy     | 2.8286183     |
# | policy_loss        | 0.00094052986 |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 24.9          |
# | total_timesteps    | 10496         |
# | value_loss         | 222034.12     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00052475586 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.72e-05     |
# | fps                | 425           |
# | n_updates          | 83            |
# | policy_entropy     | 2.8274593     |
# | policy_loss        | -0.000689076  |
# | serial_timesteps   | 10624         |
# | time_elapsed       | 25.3          |
# | total_timesteps    | 10624         |
# | value_loss         | 333088.53     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040496583 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.72e-05     |
# | fps                | 427           |
# | n_updates          | 84            |
# | policy_entropy     | 2.826304      |
# | policy_loss        | 0.0039567435  |
# | serial_timesteps   | 10752         |
# | time_elapsed       | 25.6          |
# | total_timesteps    | 10752         |
# | value_loss         | 192996.48     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014754144  |
# | clipfrac           | 0.001953125   |
# | explained_variance | -5.96e-05     |
# | fps                | 423           |
# | n_updates          | 85            |
# | policy_entropy     | 2.825658      |
# | policy_loss        | -0.0025198269 |
# | serial_timesteps   | 10880         |
# | time_elapsed       | 25.9          |
# | total_timesteps    | 10880         |
# | value_loss         | 680421.75     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.7626905e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.56e-05     |
# | fps                | 413           |
# | n_updates          | 86            |
# | policy_entropy     | 2.8246195     |
# | policy_loss        | 0.00015019625 |
# | serial_timesteps   | 11008         |
# | time_elapsed       | 26.2          |
# | total_timesteps    | 11008         |
# | value_loss         | 513023.38     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.5071246e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 4.05e-06       |
# | fps                | 422            |
# | n_updates          | 87             |
# | policy_entropy     | 2.8241954      |
# | policy_loss        | -0.00028984074 |
# | serial_timesteps   | 11136          |
# | time_elapsed       | 26.5           |
# | total_timesteps    | 11136          |
# | value_loss         | 920162.2       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023780108 |
# | clipfrac           | 0.0           |
# | explained_variance | -9.47e-05     |
# | fps                | 407           |
# | n_updates          | 88            |
# | policy_entropy     | 2.824936      |
# | policy_loss        | 0.0017777829  |
# | serial_timesteps   | 11264         |
# | time_elapsed       | 26.8          |
# | total_timesteps    | 11264         |
# | value_loss         | 1053591.6     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00031013982 |
# | clipfrac           | 0.0           |
# | explained_variance | 2.59e-05      |
# | fps                | 389           |
# | n_updates          | 89            |
# | policy_entropy     | 2.8251138     |
# | policy_loss        | -0.0026202633 |
# | serial_timesteps   | 11392         |
# | time_elapsed       | 27.1          |
# | total_timesteps    | 11392         |
# | value_loss         | 1250948.9     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00054034975  |
# | clipfrac           | 0.0            |
# | explained_variance | 1.2e-05        |
# | fps                | 407            |
# | n_updates          | 90             |
# | policy_entropy     | 2.825468       |
# | policy_loss        | -0.00063601846 |
# | serial_timesteps   | 11520          |
# | time_elapsed       | 27.4           |
# | total_timesteps    | 11520          |
# | value_loss         | 830668.1       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00039691475 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.59e-05     |
# | fps                | 422           |
# | n_updates          | 91            |
# | policy_entropy     | 2.8244495     |
# | policy_loss        | -0.0018921732 |
# ...
# Profit: 4074.751202924881
#
# Step: 1286
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1287
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1288
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1289
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1290
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1291
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1292
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1293
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1294
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1295
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1296
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1297
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1298
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1299
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1300
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1301
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1302
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1303
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1304
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1305
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1306
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1307
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1308
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1309
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1310
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1311
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1312
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1313
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1314
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1315
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1316
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1317
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1318
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1319
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1320
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1321
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1322
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1323
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1324
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1325
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1326
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1327
# Balance: 14074.751202924881
# Shares held: 0 (Total sold: 5689)
# Avg cost for held shares: 0 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1328
# Balance: 10.01024600439996
# Shares held: 1039 (Total sold: 5689)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 138234.95874118462)
# Net worth: 14074.751202924881 (Max net worth: 16976.553788064528)
# Profit: 4074.751202924881
#
# Step: 1329
# Balance: 10.01024600439996
# Shares held: 1039 (Total sold: 5689)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 138234.95874118462)
# Net worth: 13690.499932488296 (Max net worth: 16976.553788064528)
# Profit: 3690.4999324882956
#
# Step: 1330
# Balance: 8424.590674740763
# Shares held: 398 (Total sold: 6330)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 146649.539169921)
# Net worth: 13649.244357481904 (Max net worth: 16976.553788064528)
# Profit: 3649.2443574819044
#
# Step: 1331
# Balance: 8424.590674740763
# Shares held: 398 (Total sold: 6330)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 146649.539169921)
# Net worth: 13650.716678018869 (Max net worth: 16976.553788064528)
# Profit: 3650.716678018869
#
# Step: 1332
# Balance: 8424.590674740763
# Shares held: 398 (Total sold: 6330)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 146649.539169921)
# Net worth: 13775.42677095222 (Max net worth: 16976.553788064528)
# Profit: 3775.426770952219
#
# Step: 1333
# Balance: 8424.590674740763
# Shares held: 398 (Total sold: 6330)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 146649.539169921)
# Net worth: 13810.386935155959 (Max net worth: 16976.553788064528)
# Profit: 3810.386935155959
#
# Step: 1334
# Balance: 8424.590674740763
# Shares held: 398 (Total sold: 6330)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 146649.539169921)
# Net worth: 13787.608871220527 (Max net worth: 16976.553788064528)
# Profit: 3787.6088712205274
#
# Step: 1335
# Balance: 12630.031289490133
# Shares held: 85 (Total sold: 6643)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 150854.97978467034)
# Net worth: 13772.083852600985 (Max net worth: 16976.553788064528)
# Profit: 3772.0838526009848
#
# Step: 1336
# Balance: 12630.031289490133
# Shares held: 85 (Total sold: 6643)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 150854.97978467034)
# Net worth: 13785.37775155521 (Max net worth: 16976.553788064528)
# Profit: 3785.37775155521
#
# Step: 1337
# Balance: 12630.031289490133
# Shares held: 85 (Total sold: 6643)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 150854.97978467034)
# Net worth: 13818.427609535673 (Max net worth: 16976.553788064528)
# Profit: 3818.4276095356727
#
# Step: 1338
# Balance: 12630.031289490133
# Shares held: 85 (Total sold: 6643)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 150854.97978467034)
# Net worth: 13821.921165325355 (Max net worth: 16976.553788064528)
# Profit: 3821.921165325355
#
# Step: 1339
# Balance: 12630.031289490133
# Shares held: 85 (Total sold: 6643)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 150854.97978467034)
# Net worth: 13850.23794456971 (Max net worth: 16976.553788064528)
# Profit: 3850.2379445697097
#
# Step: 1340
# Balance: 12630.031289490133
# Shares held: 85 (Total sold: 6643)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 150854.97978467034)
# Net worth: 13859.067256562215 (Max net worth: 16976.553788064528)
# Profit: 3859.0672565622153
#
# Step: 1341
# Balance: 12630.031289490133
# Shares held: 85 (Total sold: 6643)
# Avg cost for held shares: 13.536805540828182 (Total sales value: 150854.97978467034)
# Net worth: 13920.034329558786 (Max net worth: 16976.553788064528)
# Profit: 3920.0343295587863
#
# Step: 1342
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 14065.777947640863 (Max net worth: 16976.553788064528)
# Profit: 4065.777947640863
#
# Step: 1343
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 14477.019498599962 (Max net worth: 16976.553788064528)
# Profit: 4477.019498599962
#
# Step: 1344
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 14834.623298237404 (Max net worth: 16976.553788064528)
# Profit: 4834.623298237404
#
# Step: 1345
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 15254.03783911811 (Max net worth: 16976.553788064528)
# Profit: 5254.037839118109
#
# Step: 1346
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 15256.33728324203 (Max net worth: 16976.553788064528)
# Profit: 5256.33728324203
#
# Step: 1347
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 15398.537158718489 (Max net worth: 16976.553788064528)
# Profit: 5398.537158718489
#
# Step: 1348
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 15512.083542687611 (Max net worth: 16976.553788064528)
# Profit: 5512.083542687611
#
# Step: 1349
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 15497.254154649065 (Max net worth: 16976.553788064528)
# Profit: 5497.254154649065
#
# Step: 1350
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 15554.228868587274 (Max net worth: 16976.553788064528)
# Profit: 5554.228868587274
#
# Step: 1351
# Balance: 12.351834918419627
# Shares held: 832 (Total sold: 6643)
# Avg cost for held shares: 16.548447025891956 (Total sales value: 150854.97978467034)
# Net worth: 15336.623971777533 (Max net worth: 16976.553788064528)
# Profit: 5336.623971777533

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.1.0'
