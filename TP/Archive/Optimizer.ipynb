# %%
from geneticalgs import BinaryGA, RealGA, DiffusionGA, MigrationGA

import numpy as np
import time

import math

import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def func(x, y):
    return abs(x*(math.sin(x/11)/5 + math.sin(x/110)) ) - y**2

# %%
# GA standard settings
generation_num = 50
population_size = 16
elitism = True
selection = 'rank'
tournament_size = None # in case of tournament selection
mut_type = 1
mut_prob = 0.05
cross_type = 1
cross_prob = 0.95
optim = 'max' # minimize or maximize a fitness value? May be 'min' or 'max'.
interval = ((0, 1000), (0,100))

# Migration GA settings
period = 5
migrant_num = 3
cloning = True

# %%
sga = RealGA(func, optim=optim, elitism=elitism, selection=selection,
            mut_type=mut_type, mut_prob=mut_prob, 
            cross_type=cross_type, cross_prob=cross_prob)

sga.init_random_population(population_size, 2, interval)

fitness_progress = sga.run(generation_num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-b26de338f9dc> in <module>()
#       3             cross_type=cross_type, cross_prob=cross_prob)
#       4
# ----> 5 sga.init_random_population(population_size, 2, interval)
#       6
#       7 fitness_progress = sga.run(generation_num)
#
# D:\Anaconda\lib\site-packages\geneticalgs\real_ga.py in init_random_population(self, size, dim, interval)
#     328                 within this interval (start point included, end point excluded).
#     329         """
# --> 330         self._check_init_random_population(size, dim, interval)
#     331
#     332         # generate population
#
# D:\Anaconda\lib\site-packages\geneticalgs\real_ga.py in _check_init_random_population(self, size, dim, interval)
#     297         if size is None or dim is None or interval is None or \
#     298                         size < 2 or dim < 1 or interval[0] >= interval[1]:
# --> 299             raise ValueError('Wrong value of input parameter.')
#     300
#     301     def _generate_random_population(self, size, dim, interval):
#
# ValueError: Wrong value of input parameter.

# %%
x2, y2 = sga.best_solution
x1 = list(range(1000))
y1 = [func(elem) for elem in x1]

plt.plot(x1, y1, label='defined function')
plt.plot(x2, y2, 'o', label='random samples')
plt.xlabel('x[float]')
plt.ylabel('y[float]')
plt.title('Visualization of defined function')
