# %%
import numpy as np

import matplotlib.pylab as plt
import seaborn as sns
sns.despine()

from data_provider import read_prices, read_data

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import Merge
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras.layers.advanced_activations import *
from keras.layers import Convolution1D, MaxPooling1D, AtrousConvolution1D
from keras.layers.recurrent import LSTM, GRU
from keras import regularizers
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def shuffle_in_unison(a, b):
    # courtsey http://stackoverflow.com/users/190280/josh-bleecher-snyder
    assert len(a) == len(b)
    shuffled_a = np.empty(a.shape, dtype=a.dtype)
    shuffled_b = np.empty(b.shape, dtype=b.dtype)
    permutation = np.random.permutation(len(a))
    for old_index, new_index in enumerate(permutation):
        shuffled_a[new_index] = a[old_index]
        shuffled_b[new_index] = b[old_index]
    return shuffled_a, shuffled_b
 
def create_Xt_Yt(X, y, percentage=0.9):
    p = int(len(X) * percentage)
    X_train = X[0:p]
    Y_train = y[0:p]
     
    X_train, Y_train = shuffle_in_unison(X_train, Y_train)
 
    X_test = X[p:]
    Y_test = y[p:]

    return X_train, X_test, Y_train, Y_test

# %%
market = 'EOS-BTC'
kline = '5m'
prices = read_prices(market, kline)
data   = np.diff(np.log(prices))

# %%
plt.plot(data) 
plt.show()

# %%
WINDOW = 30
EMB_SIZE = 1
STEP = 1
FORECAST = 1

# Straightforward way for creating time windows
X, Y = [], []
for i in range(0, len(data), STEP): 
    try:
        x_i = data[i:i+WINDOW]
        y_i = data[i+WINDOW+FORECAST]  

        last_close = x_i[WINDOW-1]
        next_close = y_i

        if last_close < next_close:
            y_i = [1, 0]
        else:
            y_i = [0, 1] 

    except Exception as e:
        print(e)
        break

    X.append(x_i)
    Y.append(y_i)

X = [(np.array(x) - np.mean(x)) / np.std(x) for x in X] # comment it to remove normalization
X, Y = np.array(X), np.array(Y)

X_train, X_test, Y_train, Y_test = create_Xt_Yt(X, Y)
# Out:
# index 19457 is out of bounds for axis 0 with size 19457

# %%
model = Sequential()
model.add(Dense(64, input_dim= WINDOW,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())
#model.add(ELU())

model.add(Dropout(0.5))
model.add(Dense(16,
                activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(LeakyReLU())
#model.add(ELU())

model.add(Dense(2))
model.add(Activation('softmax'))

opt = Nadam(lr=0.001)

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.9, patience=25, min_lr=0.000001, verbose=1)
checkpointer = ModelCheckpoint(filepath="test.hdf5", verbose=1, save_best_only=True)
model.compile(optimizer=opt, 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, 
          epochs = 30, 
          batch_size = 32, 
          verbose = 1, 
          validation_data=(X_test, Y_test),
          callbacks=[reduce_lr, checkpointer],
          shuffle=True)
# Out:
# Train on 17483 samples, validate on 1943 samples
# Epoch 1/30
# 17483/17483 [==============================] - 3s 188us/step - loss: 5.4248 - acc: 0.6264 - val_loss: 0.7112 - val_acc: 0.7324
#
# Epoch 00001: val_loss improved from inf to 0.71119, saving model to test.hdf5
# Epoch 2/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.6903 - acc: 0.7204 - val_loss: 0.6024 - val_acc: 0.7458
#
# Epoch 00002: val_loss improved from 0.71119 to 0.60235, saving model to test.hdf5
# Epoch 3/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.6163 - acc: 0.7260 - val_loss: 0.5854 - val_acc: 0.7406
#
# Epoch 00003: val_loss improved from 0.60235 to 0.58543, saving model to test.hdf5
# Epoch 4/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.6030 - acc: 0.7246 - val_loss: 0.5829 - val_acc: 0.7504
#
# Epoch 00004: val_loss improved from 0.58543 to 0.58290, saving model to test.hdf5
# Epoch 5/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5964 - acc: 0.7265 - val_loss: 0.5611 - val_acc: 0.7653
#
# Epoch 00005: val_loss improved from 0.58290 to 0.56108, saving model to test.hdf5
# Epoch 6/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5980 - acc: 0.7265 - val_loss: 0.5854 - val_acc: 0.7499
#
# Epoch 00006: val_loss did not improve from 0.56108
# Epoch 7/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5978 - acc: 0.7254 - val_loss: 0.5775 - val_acc: 0.7504
#
# Epoch 00007: val_loss did not improve from 0.56108
# Epoch 8/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5937 - acc: 0.7273 - val_loss: 0.5654 - val_acc: 0.7581
#
# Epoch 00008: val_loss did not improve from 0.56108
# Epoch 9/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5983 - acc: 0.7219 - val_loss: 0.5623 - val_acc: 0.7627
#
# Epoch 00009: val_loss did not improve from 0.56108
# Epoch 10/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5950 - acc: 0.7246 - val_loss: 0.5681 - val_acc: 0.7504
#
# Epoch 00010: val_loss did not improve from 0.56108
# Epoch 11/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5910 - acc: 0.7301 - val_loss: 0.5559 - val_acc: 0.7566
#
# Epoch 00011: val_loss improved from 0.56108 to 0.55594, saving model to test.hdf5
# Epoch 12/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5918 - acc: 0.7246 - val_loss: 0.5689 - val_acc: 0.7509
#
# Epoch 00012: val_loss did not improve from 0.55594
# Epoch 13/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5915 - acc: 0.7254 - val_loss: 0.5638 - val_acc: 0.7442
#
# Epoch 00013: val_loss did not improve from 0.55594
# Epoch 14/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5903 - acc: 0.7252 - val_loss: 0.5523 - val_acc: 0.7622
#
# Epoch 00014: val_loss improved from 0.55594 to 0.55229, saving model to test.hdf5
# Epoch 15/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5844 - acc: 0.7335 - val_loss: 0.5618 - val_acc: 0.7519
#
# Epoch 00015: val_loss did not improve from 0.55229
# Epoch 16/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5891 - acc: 0.7292 - val_loss: 0.5573 - val_acc: 0.7550
#
# Epoch 00016: val_loss did not improve from 0.55229
# Epoch 17/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5844 - acc: 0.7293 - val_loss: 0.5618 - val_acc: 0.7478
#
# Epoch 00017: val_loss did not improve from 0.55229
# Epoch 18/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5833 - acc: 0.7287 - val_loss: 0.5613 - val_acc: 0.7514
#
# Epoch 00018: val_loss did not improve from 0.55229
# Epoch 19/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5828 - acc: 0.7299 - val_loss: 0.5608 - val_acc: 0.7524
#
# Epoch 00019: val_loss did not improve from 0.55229
# Epoch 20/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5842 - acc: 0.7298 - val_loss: 0.5496 - val_acc: 0.7530
#
# Epoch 00020: val_loss improved from 0.55229 to 0.54964, saving model to test.hdf5
# Epoch 21/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5808 - acc: 0.7282 - val_loss: 0.5480 - val_acc: 0.7627
#
# Epoch 00021: val_loss improved from 0.54964 to 0.54799, saving model to test.hdf5
# Epoch 22/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5818 - acc: 0.7277 - val_loss: 0.5514 - val_acc: 0.7566
#
# Epoch 00022: val_loss did not improve from 0.54799
# Epoch 23/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5828 - acc: 0.7285 - val_loss: 0.5465 - val_acc: 0.7612
#
# Epoch 00023: val_loss improved from 0.54799 to 0.54651, saving model to test.hdf5
# Epoch 24/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5797 - acc: 0.7258 - val_loss: 0.5622 - val_acc: 0.7509
#
# Epoch 00024: val_loss did not improve from 0.54651
# Epoch 25/30
# 17483/17483 [==============================] - 2s 119us/step - loss: 0.5773 - acc: 0.7303 - val_loss: 0.5497 - val_acc: 0.7653
#
# Epoch 00025: val_loss did not improve from 0.54651
# Epoch 26/30
# 17483/17483 [==============================] - 2s 117us/step - loss: 0.5773 - acc: 0.7284 - val_loss: 0.5509 - val_acc: 0.7530
#
# Epoch 00026: val_loss did not improve from 0.54651
# Epoch 27/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5793 - acc: 0.7283 - val_loss: 0.5507 - val_acc: 0.7607
#
# Epoch 00027: val_loss did not improve from 0.54651
# Epoch 28/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5779 - acc: 0.7278 - val_loss: 0.5409 - val_acc: 0.7653
#
# Epoch 00028: val_loss improved from 0.54651 to 0.54092, saving model to test.hdf5
# Epoch 29/30
# 17483/17483 [==============================] - 2s 117us/step - loss: 0.5756 - acc: 0.7284 - val_loss: 0.5408 - val_acc: 0.7648
#
# Epoch 00029: val_loss improved from 0.54092 to 0.54085, saving model to test.hdf5
# Epoch 30/30
# 17483/17483 [==============================] - 2s 116us/step - loss: 0.5724 - acc: 0.7337 - val_loss: 0.5356 - val_acc: 0.7591
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00030: val_loss improved from 0.54085 to 0.53559, saving model to test.hdf5

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

pred = model.predict(np.array(X_test))
C = confusion_matrix([np.argmax(y) for y in Y_test], [np.argmax(y) for y in pred])

print( C / C.astype(np.float).sum(axis=1))

FROM = 0
TO = FROM + 500

original = Y_test[FROM:TO]
predicted = pred[FROM:TO] 

plt.plot(original, color='black', label = 'Original data')
plt.plot(predicted, color='blue', label = 'Predicted data')
plt.legend(loc='best')
plt.title('Actual and predicted from point %d to point %d of test set' % (FROM, TO))
plt.show()
# Out:
# [[0.74759358 0.24894515]
#  [0.30909091 0.69514768]]
